# %% [markdown]
# # **Using my YOLO model locally on VSCODE**
# This notebook explains the code steps for using your YOLO trained model and testing on local device, preferably in VSCODE IDE for inferencing.
# You can also use it withou having to use Roboflow platform

# %% [markdown]
# ## **Import Libraries**
# Install all the neccessary libraries and import them

# %%
# %pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\dolap\anaconda3\lib\site-packages (3.9.4)
# Requirement already satisfied: pillow>=8 in c:\users\dolap\anaconda3\lib\site-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dolap\anaconda3\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dolap\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dolap\anaconda3\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dolap\anaconda3\lib\site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\dolap\anaconda3\lib\site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\dolap\anaconda3\lib\site-packages (from matplotlib) (21.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dolap\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\dolap\anaconda3\lib\site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: numpy>=1.23 in c:\users\dolap\anaconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: six in c:\users\dolap\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib) (1.16.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\dolap\anaconda3\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install cv
# Out:
# Requirement already satisfied: cv in c:\users\dolap\anaconda3\lib\site-packages (1.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import torch as th

# %%
import torch
from PIL import Image
import time

# %%
# Function to load the model
def load_model(model_path):
    model = torch.load(model_path, weights_only=False)
    model.eval()  # Set the model to evaluation mode
    return model

# %%
# Function to preprocess the image before feeding it to the model
def preprocess_image(image_path):
    img = Image.open(image_path).convert("RGB")
    img = img.resize((224, 224))  # Resize to the model's expected input size
    img = np.array(img).astype(np.float32) / 255.0  # Convert to a NumPy array and normalize
    img = np.transpose(img, (2, 0, 1))  # Transpose the image to (channels, height, width)
    img = np.expand_dims(img, axis=0)  # Add a batch dimension
    return torch.tensor(img)

# %%
# %pip install ultralytics
# Out:
# Requirement already satisfied: ultralytics in c:\users\dolap\anaconda3\lib\site-packages (8.3.67)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\dolap\anaconda3\lib\site-packages (from ultralytics) (6.0)
# Requirement already satisfied: torch!=2.4.0,>=1.8.0 in c:\users\dolap\anaconda3\lib\site-packages (from ultralytics) (2.5.1)
# Requirement already satisfied: psutil in c:\users\dolap\anaconda3\lib\site-packages (from ultralytics) (5.8.0)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\dolap\anaconda3\lib\site-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\dolap\anaconda3\lib\site-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: requests>=2.23.0 in c:\users\dolap\anaconda3\lib\site-packages (from ultralytics) (2.26.0)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\dolap\anaconda3\lib\site-packages (from ultralytics) (0.20.1)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\dolap\anaconda3\lib\site-packages (from ultralytics) (8.4.0)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\dolap\anaconda3\lib\site-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\dolap\anaconda3\lib\site-packages (from ultralytics) (3.9.4)
# Requirement already satisfied: py-cpuinfo in c:\users\dolap\anaconda3\lib\site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in c:\users\dolap\anaconda3\lib\site-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\dolap\anaconda3\lib\site-packages (from ultralytics) (0.11.2)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\dolap\anaconda3\lib\site-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\dolap\anaconda3\lib\site-packages (from ultralytics) (1.3.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dolap\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\dolap\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dolap\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\dolap\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (21.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dolap\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\dolap\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (6.5.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dolap\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dolap\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: six in c:\users\dolap\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\dolap\anaconda3\lib\site-packages (from importlib-resources>=3.2.0->matplotlib>=3.3.0->ultralytics) (3.6.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\dolap\anaconda3\lib\site-packages (from pandas>=1.1.4->ultralytics) (2021.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dolap\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\dolap\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dolap\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\dolap\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2.0.4)
# Requirement already satisfied: fsspec in c:\users\dolap\anaconda3\lib\site-packages (from torch!=2.4.0,>=1.8.0->ultralytics) (2021.10.1)
# Requirement already satisfied: filelock in c:\users\dolap\anaconda3\lib\site-packages (from torch!=2.4.0,>=1.8.0->ultralytics) (3.3.1)
# Requirement already satisfied: networkx in c:\users\dolap\anaconda3\lib\site-packages (from torch!=2.4.0,>=1.8.0->ultralytics) (2.6.3)
# Requirement already satisfied: jinja2 in c:\users\dolap\anaconda3\lib\site-packages (from torch!=2.4.0,>=1.8.0->ultralytics) (2.11.3)
# Requirement already satisfied: sympy==1.13.1 in c:\users\dolap\anaconda3\lib\site-packages (from torch!=2.4.0,>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\dolap\anaconda3\lib\site-packages (from torch!=2.4.0,>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\dolap\anaconda3\lib\site-packages (from sympy==1.13.1->torch!=2.4.0,>=1.8.0->ultralytics) (1.2.1)
# Requirement already satisfied: colorama in c:\users\dolap\anaconda3\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\dolap\anaconda3\lib\site-packages (from jinja2->torch!=2.4.0,>=1.8.0->ultralytics) (1.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch

# %%
import os

# %%
# Set device (CPU or GPU)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Path to your model
model_path = "C:/Users/dolap/Downloads/best.pt"  # Use this on Windows

# %%
# Load the model
def load_model(model_path):
    model = torch.load(model_path, map_location=device)
    model.eval()
    return model.to(device)

# %% [markdown]
# ## To plot image with segmentation

# %%
from ultralytics import YOLO

# Path to your model in Downloads folder
model_path = "C:/Users/dolap/Downloads/best.pt"  # Update with your correct model path

# Load the YOLOv8 model
model = YOLO(model_path)

# Run inference on an image
image_path = "C:/Users/dolap/Downloads/cyst.jpg"  # Update with your reference image path
results = model(image_path)

# Show results
results[0].show()
# Out:
# image 1/1 C:\Users\dolap\Downloads\cyst.jpg: 640x640 1 Sargassum vulgare, 443.9ms
# Speed: 6.0ms preprocess, 443.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)

# %%
# Save annotated image to Downloads
# results[0].save(filename="C:/Users/dolap/Downloads/annotated_output.jpg")
# print("✅ Saved annotated image to Downloads")

# %%
boxes = results[0].boxes  # Bounding box coordinates
labels = results[0].names  # Class names
print(boxes)  # Print the coordinates
print(labels)  # Print the detected class names
# Out:
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.5289])
# data: tensor([[9.8340e-01, 4.0480e+01, 6.4000e+02, 6.4000e+02, 5.2886e-01, 0.0000e+00]])
# id: None
# is_track: False
# orig_shape: (640, 640)
# shape: torch.Size([1, 6])
# xywh: tensor([[320.4917, 340.2398, 639.0166, 599.5204]])
# xywhn: tensor([[0.5008, 0.5316, 0.9985, 0.9368]])
# xyxy: tensor([[  0.9834,  40.4796, 640.0000, 640.0000]])
# xyxyn: tensor([[0.0015, 0.0632, 1.0000, 1.0000]])
# {0: 'Cystoseira sp', 1: 'Posidonia oceanica', 2: 'Sargassum vulgare'}

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image

# %%
# Path to your image
image_path = "C:/Users/dolap/Downloads/cyst.jpg"

# Load the image
img = Image.open(image_path)

# Load the image in RGB mode (just in case it's not in RGB mode)
img = Image.open(image_path).convert("RGB")

# Get the bounding box data (xyxy format: [x1, y1, x2, y2])
x1, y1, x2, y2 = results[0].boxes.xyxy[0].tolist()

# Confidence and class label
confidence = results[0].boxes.conf[0].item()  # Confidence score
class_id = int(results[0].boxes.cls[0].item())  # Class ID
class_name = results[0].names[class_id]  # Get the class name from the index

# Plot the image
fig, ax = plt.subplots(1, figsize=(10, 10))
ax.imshow(img)

# %% [markdown]
# ## To plot the image with bounding box

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image

# Path to your image
image_path = "C:/Users/dolap/Downloads/cyst.jpg"

# Load the image and convert it to RGB (just in case it's grayscale or another format)
img = Image.open(image_path).convert("RGB")

# Display the raw image first to ensure it's loaded correctly
plt.imshow(img)
plt.axis('off')
plt.show()  # This step checks if the image is showing correctly

# Get the bounding box data (xyxy format: [x1, y1, x2, y2])
x1, y1, x2, y2 = results[0].boxes.xyxy[0].tolist()

# Confidence and class label
confidence = results[0].boxes.conf[0].item()  # Confidence score
class_id = int(results[0].boxes.cls[0].item())  # Class ID
class_name = results[0].names[class_id]  # Get the class name from the index

# Plot the image with the bounding box
fig, ax = plt.subplots(1, figsize=(10, 10))
ax.imshow(img)  # Display the image in RGB mode

# Create a Rectangle patch with bounding box info
rect = patches.Rectangle((x1, y1), x2 - x1, y2 - y1,
                         linewidth=2, edgecolor='r', facecolor='none')

# Add the rectangle to the image
ax.add_patch(rect)

# Annotate with class label and confidence
ax.text(x1, y1 - 10, f"{class_name} {confidence:.2f}", 
        color='red', fontsize=12, weight='bold', 
        bbox=dict(facecolor='white', alpha=0.7, edgecolor='none', boxstyle='round,pad=0.5'))

# Display the result
plt.axis('off')
plt.show()
